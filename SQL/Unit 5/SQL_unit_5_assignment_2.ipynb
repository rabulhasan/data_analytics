# %% [markdown]
# <a href="https://colab.research.google.com/github/rabulhasan/data_analytics_2/blob/main/SQL/Unit%205/SQL_unit_5_assignment_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Name: Rabiul Hasan
# Lesson 5: Joins and Unions
#
#
# ---

# %% [markdown]
# ##Join the film to the film_actor table.

# %% [markdown]
#     SELECT film.film_id, film.title, film.description,
#     film.release_year, film.language_id, film.rental_duration,
#     film.rental_rate, film.length, film.replacement_cost,
#     film.rating, film.last_update, film.special_features,
#     film.fulltext, actor_id
#     FROM film
#     FULL JOIN film_actor
#     ON film.film_id = film_actor.film_id;
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ##Join the actor table to the film_actor table.

# %% [markdown]
#     SELECT actor.actor_id, actor.first_name, actor.last_name, actor.last_update, film_actor.film_id
#     FROM actor
#     FULL JOIN film_actor
#     ON actor.actor_id = film_actor.actor_id;
#
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ##Try to join the actor, film_actor, and film table together (3 joins!)

# %% [markdown]
#     SELECT film.film_id, film.title, film.description,
#     film.release_year, film.language_id, film.rental_duration,
#     film.rental_rate, film.length, film.replacement_cost,
#     film.rating, film.last_update, film.special_features,
#     film.fulltext, film_actor.actor_id, actor.first_name, actor.last_name
#     FROM film AS film
#     FULL JOIN
#     film_actor as film_actor
#     ON film.film_id = film_actor.film_id
#     FULL JOIN
#     actor AS actor
#     ON film_actor.last_update = actor.last_update;
#
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ##Sample questions:
#
# #students with the highest marks in Unit 4:
#
#     SELECT DISTINCT first_name,student.last_name, student_marks.unit4
#     FROM student, student_marks
#     WHERE unit4 = 100;
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #students scored between 89 and 100 unit4
#
#     SELECT DISTINCT first_name,student.last_name, student_marks.unit4 FROM student, student_marks
#     WHERE unit4 BETWEEN 89 AND 100;
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ##Open ended questions:
#
#
# 1.   What is the address of the student with highest mark in unit 4?
# 2. What is the contact information of the student with hight mark in unit 4?
# 3.    Which gender like most hard copy than soft copy of a book?
# 4. What is the first name of the student who get hightest marks in all units?
# 5. What is the phone number of student live in a particuler address?
# 6. what is the email address is the first 10 students with highest marks in all units?
# 7. What is the last_name of a particuler student_id?
# 8. What is the average given marks in unit 4?
# 9. What is the mean of unit 4?
# 10. What is the median number of all unit?
